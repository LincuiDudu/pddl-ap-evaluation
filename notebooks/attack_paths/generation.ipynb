# %% [markdown]
# # PDDL Generation

# %% [markdown]
# ## Environment Setup

# %%
...

# %% [markdown]
# ## Data

# %%
...

# %% [markdown]
# ## Model

# %%
...

# %% [markdown]
# ## Generation

# %%
...
